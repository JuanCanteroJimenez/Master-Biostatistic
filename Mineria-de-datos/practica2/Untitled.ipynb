# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-87aa3c731982> in <module>
# ----> 1 data = pd.read_csv("data.csv")
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data
# Out:
#     Unnamed: 0  CodProv              NombreProv  PobTot2018  \
# 0            1        1                   Álava      328868
# 1            2        2                Albacete      388786
# 2            3        3                Alicante     1838819
# 3            4        4                 Almería      709340
# 4            5        5                   Ávila      158498
# 5            6        6                 Badajoz      676376
# 6            7        7           Illes Balears     1128908
# 7            8        8               Barcelona     5609350
# 8            9        9                  Burgos      357070
# 9           10       10                 Cáceres      396487
# 10          11       11                   Cádiz     1238714
# 11          12       12               Castellón      576898
# 12          13       13             Ciudad Real      499100
# 13          14       14                 Córdoba      785240
# 14          15       15                A Coruña     1119351
# ...

# %%
data.drop("0", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5983cc2457cc> in <module>
# ----> 1 data.drop("0", inplace=True)
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data = data.drop("Unnamed: 0", axis=1)

# %%
cod_nombre = data[["CodProv", "NombreProv"]]

# %%
cod_nombre
# Out:
#     CodProv              NombreProv
# 0         1                   Álava
# 1         2                Albacete
# 2         3                Alicante
# 3         4                 Almería
# 4         5                   Ávila
# 5         6                 Badajoz
# 6         7           Illes Balears
# 7         8               Barcelona
# 8         9                  Burgos
# 9        10                 Cáceres
# 10       11                   Cádiz
# 11       12               Castellón
# 12       13             Ciudad Real
# 13       14                 Córdoba
# 14       15                A Coruña
# 15       16                  Cuenca
# 16       17                  Girona
# 17       18                 Granada
# 18       19             Guadalajara
# 19       20                Gipuzkoa
# 20       21                  Huelva
# 21       22                  Huesca
# 22       23                    Jaén
# 23       24                    León
# 24       25                  Lleida
# ...

# %%
data = data.drop(["CodProv", "NombreProv"], axis=1)

# %%
data_ = np.array(data)

# %%
import tensorflow as tf

# %%
train_dataset = (tf.data.Dataset.from_tensor_slices(data_)
                 .shuffle(20).batch(10))

# %%
train_dataset
# Out:
# <BatchDataset shapes: (None, 16), types: tf.float64>
